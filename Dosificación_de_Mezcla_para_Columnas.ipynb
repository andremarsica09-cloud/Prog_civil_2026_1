# %% [markdown]
# <a href="https://colab.research.google.com/github/andremarsica09-cloud/Prog_civil_2026_1/blob/main/Dosificaci%C3%B3n_de_Mezcla_para_Columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dosificación de Mezcla para Columnas**
#
# **Planteamiento:**
#
# Un ingeniero residente necesita calcular cuántos sacos de cemento se requieren para vaciar una columna de sección circular.
#
# Se sabe que para un concreto estándar de 210 kg/cm2 (3000 psi), se consumen 9.5 sacos de cemento por cada metro cúbico de mezcla.
#
# **Requerimientos:**
#
# 1. Solicitar la altura de la columna en metros.
# 2. Solicitar el diámetro de la columna en metros.
# 3. Calcular el volumen de la columna: $$v=π*r^2*h$$
#
# . (Sugerencia: usar 3.1416
#  o importar math.pi).
#
# 4. Calcular la cantidad de sacos:
# $$sacos=v*9.5$$
#
# **Prueba del programa:**
#
# Para una columna de 3 metros de alto y 0.4 metros de diámetro (r=0.2
# ):
#
# Volumen ≈0.377 m3.
#
# Sacos necesarios ≈3.58
#
#  (el estudiante verá aquí la importancia de los tipos decimales).

# %%
from __future__ import print_function
# ENTRADA: Solicitar la altura de la columna en metros.
# Solicitar el diámetro de la columna en metros.
h = float(input("Ingrese la altura de la columna en metros:"))
d = float(input("Ingrese el diametro de la columna en metros:"))

# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
r = d/2
v = 3.1416*r**2 *h
sacos = v*9.5

#SALIDA: Imprime el resultado
print("Volumen = ", round (v, 3),"m3.")
print("sacos necesarios =",round(sacos , 2))
# Out:
# Ingrese la altura de la columna en metros:3
# Ingrese el diametro de la columna en metros:0.4
# Volumen =  0.377 m3.
# sacos necesarios = 3.58

# %% [markdown]
# ```markdown
# El código para el cálculo de los sacos de cemento realiza las siguientes operaciones, línea por línea:
#
# ```python
# from __future__ import print_function
# # Esta línea importa una característica del futuro de Python 3 (la función print) para asegurar compatibilidad si el código se ejecuta en Python 2. Aunque en Colab se usa Python 3, es una práctica común para asegurar la portabilidad.
#
# # ENTRADA: Solicitar la altura de la columna en metros.
# # Solicitar el diámetro de la columna en metros.
# # Estas son líneas de comentario que explican el propósito de las siguientes líneas de código.
# h = float(input("Ingrese la altura de la columna en metros:"))
# # Esta línea solicita al usuario que ingrese la altura de la columna. La entrada del usuario es una cadena de texto, y `float()` la convierte a un número decimal (punto flotante) y lo almacena en la variable `h`.
# d = float(input("Ingrese el diametro de la columna en metros:"))
# # Similar a la anterior, esta línea solicita el diámetro de la columna, lo convierte a un número decimal y lo guarda en la variable `d`.
#
# # PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
# # Otra línea de comentario que describe las operaciones de procesamiento que se realizarán.
# r = d/2
# # Calcula el radio (`r`) dividiendo el diámetro (`d`) por 2.
# v = 3.1416*r**2 *h
# # Calcula el volumen (`v`) de la columna usando la fórmula para el volumen de un cilindro: `pi * radio^2 * altura`. Se usa 3.1416 como una aproximación de pi.
# sacos = v*9.5
# # Calcula la cantidad total de sacos de cemento (`sacos`) multiplicando el volumen calculado (`v`) por la constante de 9.5 sacos por metro cúbico.
#
# #SALIDA: Imprime el resultado
# # Línea de comentario que indica el propósito de las siguientes líneas.
# print("Volumen = ", round (v, 3),"m3.")
# # Imprime el volumen calculado. `round(v, 3)` redondea el valor del volumen a 3 decimales para una mejor presentación.
# print("sacos necesarios =",round(sacos , 2))
# # Imprime la cantidad de sacos de cemento necesarios. `round(sacos, 2)` redondea el valor a 2 decimales.
# ```
